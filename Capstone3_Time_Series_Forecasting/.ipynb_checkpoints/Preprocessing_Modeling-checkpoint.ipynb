# %%
import numpy as np 
import pandas as pd

# %%
pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.23 in /Users/arlenerivera/opt/anaconda3/lib/python3.9/site-packages (from pandas_datareader) (1.4.2)
# Requirement already satisfied: requests>=2.19.0 in /Users/arlenerivera/.local/lib/python3.9/site-packages (from pandas_datareader) (2.25.1)
# Requirement already satisfied: lxml in /Users/arlenerivera/opt/anaconda3/lib/python3.9/site-packages (from pandas_datareader) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/arlenerivera/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/arlenerivera/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->pandas_datareader) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /Users/arlenerivera/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->pandas_datareader) (1.21.5)
# Requirement already satisfied: six>=1.5 in /Users/arlenerivera/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas_datareader) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/arlenerivera/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (1.26.9)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/arlenerivera/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/arlenerivera/.local/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/arlenerivera/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (2021.10.8)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
import pandas_datareader as pdr

import keras
from keras.layers import LSTM
from keras.models import Sequential
from keras.layers.wrappers import TimeDistributed
from keras.layers.core import Dense, Activation, Dropout

from sklearn.preprocessing import MinMaxScaler

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('yahoo_stock.csv')
df.head()
# Out:
#          Date         High          Low         Open        Close  \
# 0  2015-11-23  2095.610107  2081.389893  2089.409912  2086.590088
# 1  2015-11-24  2094.120117  2070.290039  2084.419922  2089.139893
# 2  2015-11-25  2093.000000  2086.300049  2089.300049  2088.870117
# 3  2015-11-26  2093.000000  2086.300049  2089.300049  2088.870117
# 4  2015-11-27  2093.290039  2084.129883  2088.820068  2090.110107
#
#          Volume    Adj Close
# 0  3.587980e+09  2086.590088
# 1  3.884930e+09  2089.139893
# 2  2.852940e+09  2088.870117
# 3  2.852940e+09  2088.870117
# 4  1.466840e+09  2090.110107

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1825 non-null   object
#  1   High       1825 non-null   float64
#  2   Low        1825 non-null   float64
#  3   Open       1825 non-null   float64
#  4   Close      1825 non-null   float64
#  5   Volume     1825 non-null   float64
#  6   Adj Close  1825 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 99.9+ KB

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1825 non-null   datetime64[ns]
#  1   High       1825 non-null   float64
#  2   Low        1825 non-null   float64
#  3   Open       1825 non-null   float64
#  4   Close      1825 non-null   float64
#  5   Volume     1825 non-null   float64
#  6   Adj Close  1825 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 99.9 KB

# %%
df["Date"].min(), df["Date"].max()
# Out:
# (Timestamp('2015-11-23 00:00:00'), Timestamp('2020-11-20 00:00:00'))

# %%
df.set_index("Date",inplace=True)
df.head()
# Out:
#                    High          Low         Open        Close        Volume  \
# Date
# 2015-11-23  2095.610107  2081.389893  2089.409912  2086.590088  3.587980e+09
# 2015-11-24  2094.120117  2070.290039  2084.419922  2089.139893  3.884930e+09
# 2015-11-25  2093.000000  2086.300049  2089.300049  2088.870117  2.852940e+09
# 2015-11-26  2093.000000  2086.300049  2089.300049  2088.870117  2.852940e+09
# 2015-11-27  2093.290039  2084.129883  2088.820068  2090.110107  1.466840e+09
#
#               Adj Close
# Date
# 2015-11-23  2086.590088
# 2015-11-24  2089.139893
# 2015-11-25  2088.870117
# 2015-11-26  2088.870117
# 2015-11-27  2090.110107

# %%
df[["High", "Low", "Open", "Close"]].plot(figsize=(10,7))
plt.legend(loc="best")
plt.xlabel("Time ---------------->")
plt.ylabel("Price ---------------->")
plt.title("Plotting Price against the Entire Timeframe For all the columns")
# Out:
# Text(0.5, 1.0, 'Plotting Price against the Entire Timeframe For all the columns')

# %%
plt.figure(figsize=(12,7))
df["High"].plot()
plt.legend(loc="best")
plt.xlabel("Time ---------------->")
plt.ylabel("Price ---------------->")
plt.title("Plotting Price against the Entire Timeframe For HIGH column")
# Out:
# Text(0.5, 1.0, 'Plotting Price against the Entire Timeframe For HIGH column')

# %% [markdown]
# All 4 plots follow the same pattern, so we can choose any.

# %%
new_df = pd.DataFrame(df["High"].copy(), columns=["High"])
new_df.head()
# Out:
#                    High
# Date
# 2015-11-23  2095.610107
# 2015-11-24  2094.120117
# 2015-11-25  2093.000000
# 2015-11-26  2093.000000
# 2015-11-27  2093.290039
