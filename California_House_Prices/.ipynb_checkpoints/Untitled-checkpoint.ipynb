# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('California_Houses.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Median_House_Value        20640 non-null  float64
#  1   Median_Income             20640 non-null  float64
#  2   Median_Age                20640 non-null  int64
#  3   Tot_Rooms                 20640 non-null  int64
#  4   Tot_Bedrooms              20640 non-null  int64
#  5   Population                20640 non-null  int64
#  6   Households                20640 non-null  int64
#  7   Latitude                  20640 non-null  float64
#  8   Longitude                 20640 non-null  float64
#  9   Distance_to_coast         20640 non-null  float64
#  10  Distance_to_LA            20640 non-null  float64
#  11  Distance_to_SanDiego      20640 non-null  float64
#  12  Distance_to_SanJose       20640 non-null  float64
#  13  Distance_to_SanFrancisco  20640 non-null  float64
# dtypes: float64(9), int64(5)
# memory usage: 2.2 MB

# %%
df.describe()
# Out:
#        Median_House_Value  Median_Income    Median_Age     Tot_Rooms  \
# count        20640.000000   20640.000000  20640.000000  20640.000000
# mean        206855.816909       3.870671     28.639486   2635.763081
# std         115395.615874       1.899822     12.585558   2181.615252
# min          14999.000000       0.499900      1.000000      2.000000
# 25%         119600.000000       2.563400     18.000000   1447.750000
# 50%         179700.000000       3.534800     29.000000   2127.000000
# 75%         264725.000000       4.743250     37.000000   3148.000000
# max         500001.000000      15.000100     52.000000  39320.000000
#
#        Tot_Bedrooms    Population    Households      Latitude     Longitude  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean     537.898014   1425.476744    499.539680     35.631861   -119.569704
# std      421.247906   1132.462122    382.329753      2.135952      2.003532
# min        1.000000      3.000000      1.000000     32.540000   -124.350000
# 25%      295.000000    787.000000    280.000000     33.930000   -121.800000
# 50%      435.000000   1166.000000    409.000000     34.260000   -118.490000
# 75%      647.000000   1725.000000    605.000000     37.710000   -118.010000
# max     6445.000000  35682.000000   6082.000000     41.950000   -114.310000
#
#        Distance_to_coast  Distance_to_LA  Distance_to_SanDiego  \
# count       20640.000000    2.064000e+04          2.064000e+04
# mean        40509.264883    2.694220e+05          3.981649e+05
# std         49140.039160    2.477324e+05          2.894006e+05
# min           120.676447    4.205891e+02          4.849180e+02
# 25%          9079.756762    3.211125e+04          1.594264e+05
# 50%         20522.019101    1.736675e+05          2.147398e+05
# 75%         49830.414479    5.271562e+05          7.057954e+05
# max        333804.686371    1.018260e+06          1.196919e+06
#
#        Distance_to_SanJose  Distance_to_SanFrancisco
# count         20640.000000              20640.000000
# mean         349187.551219             386688.422291
# std          217149.875026             250122.192316
# min             569.448118                456.141313
# 25%          113119.928682             117395.477505
# 50%          459758.877000             526546.661701
# 75%          516946.490963             584552.007907
# max          836762.678210             903627.663298

# %%
#Check number of unique dates
print('Median_House_Value:', len(df['Median_House_Value'].unique()))
# Out:
# Median_House_Value: 3842

# %%
dict = {}
for col in list(df.columns):
    dict[col] = df[col].value_counts().shape[0]

pd.DataFrame(dict,index=["unique count"]).T
# Out:
#                           unique count
# Median_House_Value                3842
# Median_Income                    12928
# Median_Age                          52
# Tot_Rooms                         5926
# Tot_Bedrooms                      1928
# Population                        3888
# Households                        1815
# Latitude                           862
# Longitude                          844
# Distance_to_coast                12590
# Distance_to_LA                   12590
# Distance_to_SanDiego             12590
# Distance_to_SanJose              12590
# Distance_to_SanFrancisco         12590

# %%
cont_col = ['Median_Income', 'Median_Age', 'Tot_Rooms', 'Tot_Bedrooms', 'Population', 'Households', 'Distance_to_coast', 
            'Distance_to_LA', 'Distance_to_SanDiego', 'Distance_to_SanJose', 'Distance_to_SanFrancisco']
loc_col = ['Latitude', 'Longitude']
dist_col = ['Distance_to_coast', 'Distance_to_LA', 'Distance_to_SanDiego', 'Distance_to_SanJose', 'Distance_to_SanFrancisco']
target = 'Median_House_Value'

# %%
df.isna().sum()
# Out:
# Median_House_Value          0
# Median_Income               0
# Median_Age                  0
# Tot_Rooms                   0
# Tot_Bedrooms                0
# Population                  0
# Households                  0
# Latitude                    0
# Longitude                   0
# Distance_to_coast           0
# Distance_to_LA              0
# Distance_to_SanDiego        0
# Distance_to_SanJose         0
# Distance_to_SanFrancisco    0
# dtype: int64

# %%
#Check for columns with na values
na_df=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).reset_index()
na_df.columns = ['VarName', 'NullCount']
na_df[(na_df['NullCount']>0)]
# Out:
# Empty DataFrame
# Columns: [VarName, NullCount]
# Index: []

# %%
No na values

# %%
# Histogram of median income.
df.hist(column="Median_House_Value")
plt.show()

# %%
df["Median_House_Value"].value_counts(dropna=False)
# Out:
# 500001.0    965
# 137500.0    122
# 162500.0    117
# 112500.0    103
# 187500.0     93
#            ...
# 359200.0      1
# 54900.0       1
# 377600.0      1
# 81200.0       1
# 47000.0       1
# Name: Median_House_Value, Length: 3842, dtype: int64

# %%
df.sort_values(by='Median_House_Value',ascending=False).head(10)
# Out:
#        Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 10667            500001.0        10.1275          27       2278           316
# 16916            500001.0         7.0422          52       2635           408
# 16946            500001.0         6.1349          33       2199           312
# 8877             500001.0         8.0257          48       2381           345
# 8878             500001.0        15.0001          52       3000           374
# 8879             500001.0         8.3839          52       2233           317
# 16941            500001.0         6.9533          44       2465           328
# 16940            500001.0         9.3694          51       2565           332
# 16939            500001.0         4.6406          50       2501           433
# 16938            500001.0        10.0743          50       1975           245
#
#        Population  Households  Latitude  Longitude  Distance_to_coast  \
# 10667         772         304     33.55    -117.88        8573.576933
# 16916         967         374     37.57    -122.34        4456.054691
# 16946         827         319     37.55    -122.33        5459.091002
# 8877          859         306     34.04    -118.49        2925.059144
# 8878         1143         375     34.04    -118.50        2579.387477
# 8879          769         277     34.04    -118.50        2579.387477
# 16941         843         324     37.55    -122.34        5967.458099
# 16940         870         309     37.55    -122.33        5459.091002
# 16939        1050         410     37.55    -122.32        5054.332607
# 16938         644         251     37.56    -122.33        4548.511495
#
#        Distance_to_LA  Distance_to_SanDiego  Distance_to_SanJose  \
# 10667    65176.733846         114396.310081        556058.424728
# 16916   537880.803256         716042.627881         47294.325414
# 16946   535678.775999         713809.781036         45356.737032
# 8877     22735.077659         192113.706104        478184.411447
# 8878     23654.837074         192711.351437        477604.972516
# 8879     23654.837074         192711.351437        477604.972516
# 16941   536298.935033         714407.783160         46109.966623
# 16940   535678.775999         713809.781036         45356.737032
# 16939   535059.415716         713212.433722         44608.261276
# 16938   536470.137431         714627.568818         45949.086011
#
#        Distance_to_SanFrancisco
# 10667             624054.364839
# 16916              24061.973816
# 16946              26452.666257
# 8877              546134.321922
# 8878              545550.049652
# 8879              545550.049652
# 16941              26169.077288
# 16940              26452.666257
# 16939              26762.215468
# 16938              25408.347148

# %%
df.plot(kind = "scatter", x = 'Median_Income', y = 'Median_House_Value', figsize = (10, 8))
plt.xlabel("Median Income", size = 15)
plt.ylabel("Median House Value", size = 15)
plt.title("Median Income vs. Median House Value", size = 20)
plt.show()

# %%
df.describe().T
# Out:
#                             count           mean            std           min  \
# Median_House_Value        20640.0  206855.816909  115395.615874  14999.000000
# Median_Income             20640.0       3.870671       1.899822      0.499900
# Median_Age                20640.0      28.639486      12.585558      1.000000
# Tot_Rooms                 20640.0    2635.763081    2181.615252      2.000000
# Tot_Bedrooms              20640.0     537.898014     421.247906      1.000000
# Population                20640.0    1425.476744    1132.462122      3.000000
# Households                20640.0     499.539680     382.329753      1.000000
# Latitude                  20640.0      35.631861       2.135952     32.540000
# Longitude                 20640.0    -119.569704       2.003532   -124.350000
# Distance_to_coast         20640.0   40509.264883   49140.039160    120.676447
# Distance_to_LA            20640.0  269421.981646  247732.446134    420.589109
# Distance_to_SanDiego      20640.0  398164.933494  289400.563735    484.917973
# Distance_to_SanJose       20640.0  349187.551219  217149.875026    569.448118
# Distance_to_SanFrancisco  20640.0  386688.422291  250122.192316    456.141313
#
#                                     25%            50%            75%  \
# Median_House_Value        119600.000000  179700.000000  264725.000000
# Median_Income                  2.563400       3.534800       4.743250
# Median_Age                    18.000000      29.000000      37.000000
# Tot_Rooms                   1447.750000    2127.000000    3148.000000
# Tot_Bedrooms                 295.000000     435.000000     647.000000
# Population                   787.000000    1166.000000    1725.000000
# Households                   280.000000     409.000000     605.000000
# Latitude                      33.930000      34.260000      37.710000
# Longitude                   -121.800000    -118.490000    -118.010000
# Distance_to_coast           9079.756762   20522.019101   49830.414479
# Distance_to_LA             32111.253908  173667.461747  527156.235384
# Distance_to_SanDiego      159426.394646  214739.830318  705795.399035
# Distance_to_SanJose       113119.928682  459758.877000  516946.490963
# Distance_to_SanFrancisco  117395.477505  526546.661701  584552.007907
#
#                                    max
# Median_House_Value        5.000010e+05
# Median_Income             1.500010e+01
# Median_Age                5.200000e+01
# Tot_Rooms                 3.932000e+04
# Tot_Bedrooms              6.445000e+03
# Population                3.568200e+04
# Households                6.082000e+03
# Latitude                  4.195000e+01
# Longitude                -1.143100e+02
# Distance_to_coast         3.338047e+05
# Distance_to_LA            1.018260e+06
# Distance_to_SanDiego      1.196919e+06
# Distance_to_SanJose       8.367627e+05
# Distance_to_SanFrancisco  9.036277e+05

# %%
fig, ax = plt.subplots(1, 2, figsize=[10, 5])
sns.regplot(data=df, x="Median_Income", y="Median_House_Value",
            line_kws={"color": "red"}, scatter_kws={"alpha":0.1}, ax=ax[0])
sns.regplot(data=df, x="Distance_to_coast",
            y="Median_House_Value", line_kws={"color": "red"},
            scatter_kws={"alpha":0.1}, ax=ax[1])
ax[0].set(ylim=(0, 550000))
ax[1].set(ylim=(0, 550000))
fig.tight_layout()
plt.show()

# %%
Median house value & median income have a positive correlation, whereas median house value & distance to coast has a negative correlation.

# %%
df.hist(figsize=(15,15))
plt.subplots_adjust(hspace=0.5);

# %%
#Identify outliers with Interquartile Range (IQR)
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Median_House_Value          145125.000000
# Median_Income                    2.179850
# Median_Age                      19.000000
# Tot_Rooms                     1700.250000
# Tot_Bedrooms                   352.000000
# Population                     938.000000
# Households                     325.000000
# Latitude                         3.780000
# Longitude                        3.790000
# Distance_to_coast            40750.657717
# Distance_to_LA              495044.981476
# Distance_to_SanDiego        546369.004388
# Distance_to_SanJose         403826.562281
# Distance_to_SanFrancisco    467156.530402
# dtype: float64

# %%
print(df[cont_col].skew())
print(df[loc_col].skew())
print(df[dist_col].skew())
print(df[target].skew())
# Out:
# Median_Income               1.646657
# Median_Age                  0.060331
# Tot_Rooms                   4.147343
# Tot_Bedrooms                3.453073
# Population                  4.935858
# Households                  3.410438
# Distance_to_coast           1.938709
# Distance_to_LA              0.466536
# Distance_to_SanDiego        0.384936
# Distance_to_SanJose        -0.223069
# Distance_to_SanFrancisco   -0.263499
# dtype: float64
# Latitude     0.465953
# Longitude   -0.297801
# dtype: float64
# Distance_to_coast           1.938709
# Distance_to_LA              0.466536
# Distance_to_SanDiego        0.384936
# Distance_to_SanJose        -0.223069
# Distance_to_SanFrancisco   -0.263499
# dtype: float64
# 0.9777632739098341

# %%
skew = ['Tot_Rooms', 'Tot_Bedrooms', 'Population', 'Households']

# %%
df.boxplot(figsize=(15,16))
plt.subplots_adjust(hspace=0.5);

# %%
plt.boxplot(df[skew])
plt.xticks([1, 2, 3, 4],  ['Tot_Rooms', 'Tot_Bedrooms', 'Population', 'Households'])
plt.show()

# %%
plt.figure(figsize=(20, 12))
for i, column in enumerate(cont_col, 1):
    plt.subplot(3, 4, i)
    sns.histplot(x=df[column],color='indianred', kde=True)
    plt.xlabel(column)

# %%
df.median()
# Out:
# Median_House_Value          179700.000000
# Median_Income                    3.534800
# Median_Age                      29.000000
# Tot_Rooms                     2127.000000
# Tot_Bedrooms                   435.000000
# Population                    1166.000000
# Households                     409.000000
# Latitude                        34.260000
# Longitude                     -118.490000
# Distance_to_coast            20522.019101
# Distance_to_LA              173667.461747
# Distance_to_SanDiego        214739.830318
# Distance_to_SanJose         459758.877000
# Distance_to_SanFrancisco    526546.661701
# dtype: float64

# %%
#Median_Income is measure in increments of 10K
df['New_Median_House_Value'] = df['Median_House_Value'].multiply(1/10000) 
df['Years_to_Buy'] = df['New_Median_House_Value']/df['Median_Income']

# %%
df.median()
# Out:
# Median_House_Value          179700.000000
# Median_Income                    3.534800
# Median_Age                      29.000000
# Tot_Rooms                     2127.000000
# Tot_Bedrooms                   435.000000
# Population                    1166.000000
# Households                     409.000000
# Latitude                        34.260000
# Longitude                     -118.490000
# Distance_to_coast            20522.019101
# Distance_to_LA              173667.461747
# Distance_to_SanDiego        214739.830318
# Distance_to_SanJose         459758.877000
# Distance_to_SanFrancisco    526546.661701
# New_Median_House_Value          17.970000
# Years_to_Buy                     4.950018
# dtype: float64

# %%
from plotnine import *
import matplotlib.style as style
style.use('ggplot')
import warnings
warnings.filterwarnings("ignore")
(
ggplot(data = df)+
    geom_point(mapping=aes(x='Longitude',y='Latitude',
                           size='Population',color='Median_House_Value'),alpha=0.4) +
    labs(title='California Median House Price')
)
# Out:
# <ggplot: (8761868939963)>

# %%
sns.lmplot(x="Population", y="Tot_Rooms", data=df, line_kws={"color": "red"})

# %%
ex1 = df.groupby(['Median_Age'], as_index=False).mean().sort_values(['Median_Income'])

sns.lineplot(x='Median_Age', y='Median_Income', data=ex1)
#plt.xticks(rotation=-45)
# Out:
# <AxesSubplot:xlabel='Median_Age', ylabel='Median_Income'>

# %%
Somehow children under the age of 8 have a higher median income than actual adults.

# %%
#plt.subplots(figsize=(12,10))
#sns.heatmap(df.corr());
dfCorr = df.corr()
filteredDf = dfCorr[((dfCorr >= .4) | (dfCorr <= -.4)) & (dfCorr !=1.00)]
plt.figure(figsize=(15,15))
sns.heatmap(filteredDf, annot=True, cmap="Reds")
plt.show()

# %%
df.corr()
# Out:
#                           Median_House_Value  Median_Income  Median_Age  \
# Median_House_Value                  1.000000       0.688075    0.105623
# Median_Income                       0.688075       1.000000   -0.119034
# Median_Age                          0.105623      -0.119034    1.000000
# Tot_Rooms                           0.134153       0.198050   -0.361262
# Tot_Bedrooms                        0.050594      -0.008093   -0.320485
# Population                         -0.024650       0.004834   -0.296244
# Households                          0.065843       0.013033   -0.302916
# Latitude                           -0.144160      -0.079809    0.011173
# Longitude                          -0.045967      -0.015176   -0.108197
# Distance_to_coast                  -0.469350      -0.243443   -0.226621
# Distance_to_LA                     -0.130678      -0.065421   -0.031435
# Distance_to_SanDiego               -0.092510      -0.055253    0.036113
# Distance_to_SanJose                -0.041590      -0.036796   -0.089753
# Distance_to_SanFrancisco           -0.030559      -0.022424   -0.101447
# New_Median_House_Value              1.000000       0.688075    0.105623
# Years_to_Buy                        0.442203      -0.192902    0.202430
#
#                           Tot_Rooms  Tot_Bedrooms  Population  Households  \
# Median_House_Value         0.134153      0.050594   -0.024650    0.065843
# Median_Income              0.198050     -0.008093    0.004834    0.013033
# Median_Age                -0.361262     -0.320485   -0.296244   -0.302916
# Tot_Rooms                  1.000000      0.929893    0.857126    0.918484
# Tot_Bedrooms               0.929893      1.000000    0.878026    0.979829
# Population                 0.857126      0.878026    1.000000    0.907222
# Households                 0.918484      0.979829    0.907222    1.000000
# Latitude                  -0.036100     -0.066318   -0.108785   -0.071035
# Longitude                  0.044568      0.068378    0.099773    0.055310
# Distance_to_coast         -0.001540     -0.022290   -0.040273   -0.062035
# Distance_to_LA            -0.019777     -0.055809   -0.110407   -0.062118
# Distance_to_SanDiego      -0.038935     -0.067627   -0.109691   -0.069091
# Distance_to_SanJose        0.031862      0.059663    0.079117    0.047861
# Distance_to_SanFrancisco   0.032920      0.060250    0.088618    0.050157
# New_Median_House_Value     0.134153      0.050594   -0.024650    0.065843
# Years_to_Buy              -0.068574      0.050730   -0.032363    0.047239
#
#                           Latitude  Longitude  Distance_to_coast  \
# Median_House_Value       -0.144160  -0.045967          -0.469350
# Median_Income            -0.079809  -0.015176          -0.243443
# Median_Age                0.011173  -0.108197          -0.226621
# Tot_Rooms                -0.036100   0.044568          -0.001540
# Tot_Bedrooms             -0.066318   0.068378          -0.022290
# Population               -0.108785   0.099773          -0.040273
# Households               -0.071035   0.055310          -0.062035
# Latitude                  1.000000  -0.924664           0.303645
# Longitude                -0.924664   1.000000           0.007865
# Distance_to_coast         0.303645   0.007865           1.000000
# Distance_to_LA            0.941857  -0.892026           0.197672
# Distance_to_SanDiego      0.991571  -0.958315           0.214531
# Distance_to_SanJose      -0.855075   0.923991          -0.077524
# Distance_to_SanFrancisco -0.897397   0.954864          -0.068248
# New_Median_House_Value   -0.144160  -0.045967          -0.469350
# Years_to_Buy             -0.111623  -0.012278          -0.316096
#
#                           Distance_to_LA  Distance_to_SanDiego  \
# Median_House_Value             -0.130678             -0.092510
# Median_Income                  -0.065421             -0.055253
# Median_Age                     -0.031435              0.036113
# Tot_Rooms                      -0.019777             -0.038935
# Tot_Bedrooms                   -0.055809             -0.067627
# Population                     -0.110407             -0.109691
# Households                     -0.062118             -0.069091
# Latitude                        0.941857              0.991571
# Longitude                      -0.892026             -0.958315
# Distance_to_coast               0.197672              0.214531
# Distance_to_LA                  1.000000              0.951459
# Distance_to_SanDiego            0.951459              1.000000
# Distance_to_SanJose            -0.794024             -0.887636
# Distance_to_SanFrancisco       -0.848657             -0.927850
# New_Median_House_Value         -0.130678             -0.092510
# Years_to_Buy                   -0.111800             -0.077909
#
#                           Distance_to_SanJose  Distance_to_SanFrancisco  \
# Median_House_Value                  -0.041590                 -0.030559
# Median_Income                       -0.036796                 -0.022424
# Median_Age                          -0.089753                 -0.101447
# Tot_Rooms                            0.031862                  0.032920
# Tot_Bedrooms                         0.059663                  0.060250
# Population                           0.079117                  0.088618
# Households                           0.047861                  0.050157
# Latitude                            -0.855075                 -0.897397
# Longitude                            0.923991                  0.954864
# Distance_to_coast                   -0.077524                 -0.068248
# Distance_to_LA                      -0.794024                 -0.848657
# Distance_to_SanDiego                -0.887636                 -0.927850
# Distance_to_SanJose                  1.000000                  0.989872
# Distance_to_SanFrancisco             0.989872                  1.000000
# New_Median_House_Value              -0.041590                 -0.030559
# Years_to_Buy                         0.009995                  0.008863
#
#                           New_Median_House_Value  Years_to_Buy
# Median_House_Value                      1.000000      0.442203
# Median_Income                           0.688075     -0.192902
# Median_Age                              0.105623      0.202430
# Tot_Rooms                               0.134153     -0.068574
# Tot_Bedrooms                            0.050594      0.050730
# Population                             -0.024650     -0.032363
# Households                              0.065843      0.047239
# Latitude                               -0.144160     -0.111623
# Longitude                              -0.045967     -0.012278
# Distance_to_coast                      -0.469350     -0.316096
# Distance_to_LA                         -0.130678     -0.111800
# Distance_to_SanDiego                   -0.092510     -0.077909
# Distance_to_SanJose                    -0.041590      0.009995
# Distance_to_SanFrancisco               -0.030559      0.008863
# New_Median_House_Value                  1.000000      0.442203
# Years_to_Buy                            0.442203      1.000000

# %%
plt.figure(figsize = (20,10))
corrmatrix = df.corr()
 
columnss = corrmatrix.nlargest(len(df), target)[target].index
cm = np.corrcoef(df[columnss].values.T)
sns.set(font_scale = 1)
hm = sns.heatmap(cm, cbar = True, annot = True, square = True, cmap = "RdPu" ,  fmt = ".2f", annot_kws = {"size": 10},
                     yticklabels = columnss.values, xticklabels = columnss.values)
plt.show()

# %%
The heatmap shows that household, population, total bedrooms, and distance to coast have a correlation higher than 0.9
